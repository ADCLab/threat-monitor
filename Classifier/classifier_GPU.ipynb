# %%
# Imports
from imblearn.pipeline import Pipeline  # imblearn's pipeline supports resampling steps
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score, confusion_matrix
import pandas as pd
import numpy as np
import os
# Disable tokenizers parallelism to avoid deadlocks
os.environ["TOKENIZERS_PARALLELISM"] = "false"
import torch
import re
from torch.nn import CrossEntropyLoss
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer
import accelerate
import optuna
from sklearn.metrics import precision_recall_fscore_support, accuracy_score
torch.cuda.is_available()
# Out:
# True

# %%
directory = r"/home/noarchway/PycharmProjects/threat-monitor/Classifier/dataset"
df = pd.DataFrame()
for name in os.listdir(directory):
    with open(os.path.join(directory, name)) as f:
        print(f"Content of '{name}'")
        csvdf = pd.read_csv(f)
        df = pd.concat([df, csvdf])
print("Original df shape:", df.shape)
# Out:
# Content of 'output_04.csv'
# Content of 'output_05.csv'
# Content of 'output_03.csv'
# Content of 'output_06.csv'
# Content of 'output_02.csv'
# Content of 'output_01.csv'
# Original df shape: (509073, 15)

# %%
# Create a new DataFrame with only the necessary columns and rename them
values = df[['Rating', 'Content']].copy()
values.rename(columns={'Rating': 'label', 'Content': 'text'}, inplace=True)
# Map ratings: 1 and 2 become 0; 3, 4, 5 (and NaN) become 1
values['label'] = values['label'].map({1: 0, 2: 0, 3: 1, 4: 1, 5: 1, np.nan: 1})
values.dropna(subset=['text'], inplace=True)

# Convert columns to lists for tokenization
texts = values['text'].tolist()
labels = values['label'].tolist()

def normalize_text(text):
    # Remove HTML tags if any
    text = re.sub(r'<.*?>', '', text)
    # Remove extra whitespace and strip leading/trailing spaces
    text = re.sub(r'\s+', ' ', text).strip()
    # Convert text to lowercase (optional since the model is uncased)
    text = text.lower()
    return text

# Apply normalization to your texts
texts = [normalize_text(t) for t in texts]

# Split into training and test sets
train_texts, test_texts, train_labels, test_labels = train_test_split(
    texts, labels, test_size=0.2, random_state=42
)

# %% [markdown]
# Tokenize all of the text, essentially tokenizing will return a list of lists with additional data. The lists are individual texts and labels that get encoded so broken down into tokens and then returns the list of id's that make up that text and gets padded out to length 128

# %%
model_name = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Tokenize the text, breaks the text down into tokens and encodes the location like a hashmap
train_encodings = tokenizer(train_texts, truncation=True, padding=True, max_length=128)
test_encodings = tokenizer(test_texts, truncation=True, padding=True, max_length=128)

# Create a PyTorch dataset
class TextDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels
    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item
    def __len__(self):
        return len(self.labels)

train_dataset = TextDataset(train_encodings, train_labels)
test_dataset = TextDataset(test_encodings, test_labels)

# %%
# Class frequencies
freq_0 = 87192
freq_1 = 12808
total_samples = freq_0 + freq_1  # 100000 in this example
num_classes = 2

# Compute weights: total_samples / (num_classes * class_frequency)
w0 = total_samples / (num_classes * freq_0)
w1 = total_samples / (num_classes * freq_1)

# Now create a tensor for the weights
class_weights = torch.tensor([w0, w1]).float().cuda()  # If you're using GPU

print("Class Weights:", class_weights)
# Out:
# Class Weights: tensor([0.5734, 3.9038], device='cuda:0')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
class_weights = torch.tensor([w0, w1]).float().to(device)

class WeightedModel(torch.nn.Module):
    def __init__(self, base_model, weights):
        super().__init__()
        self.base_model = base_model
        self.weights = weights

    def forward(self, input_ids=None, attention_mask=None, labels=None, **kwargs):
        # Remove the extra keyword if it exists
        kwargs.pop('num_items_in_batch', None)
        # Call the base model without the unexpected argument
        outputs = self.base_model(input_ids, attention_mask=attention_mask, labels=None, **kwargs)
        logits = outputs.logits
        if labels is not None:
            loss_fct = torch.nn.CrossEntropyLoss(weight=self.weights)
            loss = loss_fct(logits, labels)
            return (loss, logits)
        return (logits,)

base_model = AutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased", num_labels=2)
model = WeightedModel(base_model, class_weights)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model_name = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='binary')
    accuracy = accuracy_score(labels, preds)
    return {'accuracy': accuracy, 'precision': precision, 'recall': recall, 'f1': f1}

def model_init():
    base_model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)
    weighted_model = WeightedModel(base_model, class_weights)
    return weighted_model


def objective(trial):
    training_args = TrainingArguments(
        output_dir="./results",
        num_train_epochs=3,
        per_device_train_batch_size=32,
        per_device_eval_batch_size=64,
        learning_rate=2.2786275995431975e-05,
        weight_decay=0.00010005716374558712,
        eval_strategy="epoch",
        save_strategy="epoch",
        logging_dir='./logs',
        load_best_model_at_end=True,
        metric_for_best_model="f1"
    )

    trainer = Trainer(
        model_init=model_init,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics,
    )

    try:
        trainer.train()
        eval_result = trainer.evaluate()
        return eval_result["eval_f1"]
    except Exception as e:
        print(f"Trial failed due to: {e}")
        return 0.0  # Return a minimal value to ignore this trial

# %%
study = optuna.create_study(direction="maximize")  # maximize the F1-score
study.optimize(objective, n_trials=10)

print("Best trial:")
trial = study.best_trial

print(f"  F1: {trial.value}")
print("  Best hyperparameters:")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2025-04-03 20:29:06,768] A new study created in memory with name: no-name-c5afb08a-70da-4a88-b154-fc3e33d15633
# /tmp/ipykernel_206918/1170152378.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate=trial.suggest_loguniform("learning_rate", 5e-6, 5e-4),
# /tmp/ipykernel_206918/1170152378.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   weight_decay=trial.suggest_loguniform("weight_decay", 1e-5, 1e-2),
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='50908' max='50908' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50908/50908 1:21:49, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.347100</td>
#       <td>0.375682</td>
#       <td>0.899966</td>
#       <td>0.615900</td>
#       <td>0.755954</td>
#       <td>0.678778</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.259500</td>
#       <td>0.397896</td>
#       <td>0.917930</td>
#       <td>0.681979</td>
#       <td>0.773867</td>
#       <td>0.725023</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.182400</td>
#       <td>0.477033</td>
#       <td>0.923027</td>
#       <td>0.703602</td>
#       <td>0.776607</td>
#       <td>0.738304</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.125900</td>
#       <td>0.714795</td>
#       <td>0.930649</td>
#       <td>0.754903</td>
#       <td>0.746259</td>
#       <td>0.750556</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1591' max='1591' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1591/1591 01:26]
#     </div>
# [I 2025-04-03 21:52:28,610] Trial 0 finished with value: 0.7505563994771611 and parameters: {'num_train_epochs': 4, 'per_device_train_batch_size': 32, 'learning_rate': 2.2786275995431975e-05, 'weight_decay': 0.00010005716374558712}. Best is trial 0 with value: 0.7505563994771611.
# /tmp/ipykernel_206918/1170152378.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate=trial.suggest_loguniform("learning_rate", 5e-6, 5e-4),
# /tmp/ipykernel_206918/1170152378.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   weight_decay=trial.suggest_loguniform("weight_decay", 1e-5, 1e-2),
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='101816' max='101816' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [101816/101816 1:33:39, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.542600</td>
#       <td>0.564320</td>
#       <td>0.868841</td>
#       <td>0.531503</td>
#       <td>0.522093</td>
#       <td>0.526756</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.486400</td>
#       <td>0.522719</td>
#       <td>0.858685</td>
#       <td>0.495997</td>
#       <td>0.665894</td>
#       <td>0.568524</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.437800</td>
#       <td>0.454671</td>
#       <td>0.867357</td>
#       <td>0.519223</td>
#       <td>0.692589</td>
#       <td>0.593504</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.391700</td>
#       <td>0.574244</td>
#       <td>0.885773</td>
#       <td>0.584572</td>
#       <td>0.632455</td>
#       <td>0.607572</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1591' max='1591' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1591/1591 01:25]
#     </div>
# [I 2025-04-03 23:27:38,281] Trial 1 finished with value: 0.6075718720475097 and parameters: {'num_train_epochs': 4, 'per_device_train_batch_size': 16, 'learning_rate': 7.750458657601906e-05, 'weight_decay': 6.381823894589006e-05}. Best is trial 0 with value: 0.7505563994771611.
# /tmp/ipykernel_206918/1170152378.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate=trial.suggest_loguniform("learning_rate", 5e-6, 5e-4),
# /tmp/ipykernel_206918/1170152378.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   weight_decay=trial.suggest_loguniform("weight_decay", 1e-5, 1e-2),
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='19183' max='254540' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 19183/254540 10:39 < 2:10:50, 29.98 it/s, Epoch 0.38/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# [W 2025-04-03 23:38:22,921] Trial 2 failed with parameters: {'num_train_epochs': 5, 'per_device_train_batch_size': 8, 'learning_rate': 1.7991462496474703e-05, 'weight_decay': 0.0007341405950115151} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/noarchway/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_206918/1170152378.py", line 41, in objective
#     trainer.train()
#   File "/home/noarchway/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/transformers/trainer.py", line 2245, in train
#     return inner_training_loop(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/noarchway/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/transformers/trainer.py", line 2556, in _inner_training_loop
#     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/noarchway/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/transformers/trainer.py", line 3764, in training_step
#     self.accelerator.backward(loss, **kwargs)
#   File "/home/noarchway/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/accelerate/accelerator.py", line 2454, in backward
#     loss.backward(**kwargs)
#   File "/home/noarchway/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/torch/_tensor.py", line 626, in backward
#     torch.autograd.backward(
#   File "/home/noarchway/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/torch/autograd/__init__.py", line 347, in backward
#     _engine_run_backward(
#   File "/home/noarchway/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/torch/autograd/graph.py", line 823, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# [W 2025-04-03 23:38:22,926] Trial 2 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 2
#       1 study = optuna.create_study(direction="maximize")  # maximize the F1-score
# ----> 2 study.optimize(objective, n_trials=10)
#       4 print("Best trial:")
#       5 trial = study.best_trial
#
# File ~/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/optuna/study/study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)    382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File ~/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File ~/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/optuna/study/_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File ~/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/optuna/study/_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[34], line 41, in objective(trial)
#      32 trainer = Trainer(
#      33     model_init=model_init,
#      34     args=training_args,
#    (...)     37     compute_metrics=compute_metrics,
#      38 )
#      40 try:
# ---> 41     trainer.train()
#      42     eval_result = trainer.evaluate()
#      43     return eval_result["eval_f1"]
#
# File ~/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/transformers/trainer.py:2245, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2243         hf_hub_utils.enable_progress_bars()
#    2244 else:
# -> 2245     return inner_training_loop(
#    2246         args=args,
#    2247         resume_from_checkpoint=resume_from_checkpoint,
#    2248         trial=trial,
#    2249         ignore_keys_for_eval=ignore_keys_for_eval,
#    2250     )
#
# File ~/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/transformers/trainer.py:2556, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2549 context = (
#    2550     functools.partial(self.accelerator.no_sync, model=model)
#    2551     if i != len(batch_samples) - 1
#    2552     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2553     else contextlib.nullcontext
#    2554 )
#    2555 with context():
# -> 2556     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2558 if (
#    2559     args.logging_nan_inf_filter
#    2560     and not is_torch_xla_available()
#    2561     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2562 ):
#    2563     # if loss is nan or inf simply add the average of previous logged losses
#    2564     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/transformers/trainer.py:3764, in Trainer.training_step(***failed resolving arguments***)
#    3761 if self.accelerator.distributed_type == DistributedType.DEEPSPEED:
#    3762     kwargs["scale_wrt_gas"] = False
# -> 3764 self.accelerator.backward(loss, **kwargs)
#    3766 return loss.detach()
#
# File ~/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/accelerate/accelerator.py:2454, in Accelerator.backward(self, loss, **kwargs)
#    2452     self.lomo_backward(loss, learning_rate)
#    2453 else:
# -> 2454     loss.backward(**kwargs)
#
# File ~/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)    624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/PycharmProjects/threat-monitor/.venv/lib/python3.12/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# Best trial
trial = study.best_trial

print("Best F1-score:", trial.value)
print("Best Hyperparameters:")
for key, value in trial.params.items():
    print(f"  {key}: {value}")
# Out:
# Best F1-score: 0.7505563994771611
# Best Hyperparameters:
#   num_train_epochs: 4
#   per_device_train_batch_size: 32
#   learning_rate: 2.2786275995431975e-05
#   weight_decay: 0.00010005716374558712
